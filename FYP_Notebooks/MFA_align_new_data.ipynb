# %% [markdown]
# Copy data from colab

# %%
from google.colab import drive

drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %%
# !unzip /content/gdrive/MyDrive/FYP_Notebooks/dataverse.zip -d /content/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dataverse/wavs/OAF_fail_happy.wav
#   inflating: /content/__MACOSX/dataverse/wavs/._OAF_fail_happy.wav
#   inflating: /content/dataverse/wavs/OAF_said_sad.wav
#   inflating: /content/__MACOSX/dataverse/wavs/._OAF_said_sad.wav
#   inflating: /content/dataverse/wavs/OAF_said_disgust.wav
#   inflating: /content/__MACOSX/dataverse/wavs/._OAF_said_disgust.wav
#   inflating: /content/dataverse/wavs/OAF_lease_happy.wav
#   inflating: /content/__MACOSX/dataverse/wavs/._OAF_lease_happy.wav
#   inflating: /content/dataverse/wavs/OAF_far_ps.wav
#   inflating: /content/__MACOSX/dataverse/wavs/._OAF_far_ps.wav
#   inflating: /content/dataverse/wavs/YAF_mode_angry.wav
#   inflating: /content/__MACOSX/dataverse/wavs/._YAF_mode_angry.wav
#   inflating: /content/dataverse/wavs/YAF_dip_ps.wav
#   inflating: /content/__MACOSX/dataverse/wavs/._YAF_dip_ps.wav
#   inflating: /content/dataverse/wavs/OAF_name_sad.wav
# ...

# %% [markdown]
# Install conda environment

# %%
# !which python # should return /usr/local/bin/python
# Out:
# /usr/local/bin/python

# %%
# !python --version
# Out:
# Python 3.8.16

# %%
# !echo $PYTHONPATH

# %%
# %env PYTHONPATH=
# Out:
# env: PYTHONPATH=

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-py37_4.12.0-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX
# Out:
# PREFIX=/usr/local
# Unpacking payload ...
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - _openmp_mutex==4.5=1_gnu
#     - brotlipy==0.7.0=py37h27cfd23_1003
#     - ca-certificates==2022.3.29=h06a4308_1
#     - certifi==2021.10.8=py37h06a4308_2
#     - cffi==1.15.0=py37hd667e15_1
#     - charset-normalizer==2.0.4=pyhd3eb1b0_0
#     - colorama==0.4.4=pyhd3eb1b0_0
#     - conda-content-trust==0.1.1=pyhd3eb1b0_0
#     - conda-package-handling==1.8.1=py37h7f8727e_0
#     - conda==4.12.0=py37h06a4308_0
#     - cryptography==36.0.0=py37h9ce1e76_0
#     - idna==3.3=pyhd3eb1b0_0
#     - ld_impl_linux-64==2.35.1=h7274673_9
#     - libffi==3.3=he6710b0_2
#     - libgcc-ng==9.3.0=h5101ec6_17
#     - libgomp==9.3.0=h5101ec6_17
#     - libstdcxx-ng==9.3.0=hd4cf53a_17
#     - ncurses==6.3=h7f8727e_2
#     - openssl==1.1.1n=h7f8727e_0
#     - pip==21.2.2=py37h06a4308_0
# ...

# %%
# !which conda # should return /usr/local/bin/conda
# Out:
# /usr/local/bin/conda

# %%
# !conda --version # should return 4.12.0
# Out:
# conda 4.12.0

# %%
# !python --version # now returns Python 3.7.13 :: Anaconda, Inc.
# Out:
# Python 3.7.13

# %%
# %%bash
# conda install --channel defaults conda python=3.9 --yes
# conda update --channel defaults --all --yes
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.9
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotlipy-0.7.0             |py39h27cfd23_1003         324 KB
#     ca-certificates-2022.10.11 |       h06a4308_0         124 KB
#     certifi-2022.12.7          |   py39h06a4308_0         150 KB
#     cffi-1.15.1                |   py39h74dc2b5_0         228 KB
#     conda-22.11.1              |   py39h06a4308_4         927 KB
#     conda-package-handling-2.0.2|   py39h06a4308_0         267 KB
#     conda-package-streaming-0.7.0|   py39h06a4308_0          26 KB
#     cryptography-38.0.1        |   py39h9ce1e76_0         1.3 MB
#     libgcc-ng-11.2.0           |       h1234567_1         5.3 MB
#     libgomp-11.2.0             |       h1234567_1         474 KB
# ...

# %%
# !conda --version # now returns 22.11.1
# Out:
# conda 22.11.1

# %%
# !python --version
# Out:
# Python 3.9.15

# %%
import sys
sys.path
# Out:
# ['/content',
#  '/env/python',
#  '/usr/lib/python38.zip',
#  '/usr/lib/python3.8',
#  '/usr/lib/python3.8/lib-dynload',
#  '',
#  '/usr/local/lib/python3.8/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.8/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
import sys
_ = (sys.path
        .append("/usr/local/lib/python3.9/site-packages"))

# %%
# !which python
# Out:
# /usr/local/bin/python

# %%
# !conda config --add channels conda-forge

# %%
# !conda install montreal-forced-aligner
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - montreal-forced-aligner
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |       2_kmp_llvm           6 KB  conda-forge
#     ansiwrap-0.8.4             |             py_0           9 KB  conda-forge
#     aom-3.5.0                  |       h27087fc_0         2.7 MB  conda-forge
#     appdirs-1.4.4              |     pyh9f0ad1d_0          13 KB  conda-forge
#     atk-1.0-2.38.0             |       hd4edc92_1         539 KB  conda-forge
#     audioread-3.0.0            |   py39hf3d152e_1          34 KB  conda-forge
#     baumwelch-0.3.7            |       h924138e_3         452 KB  conda-forge
# ...

# %%
# dounload dictionary and accustic model 
# %%bash
mfa model download acoustic english_us_arpa
mfa model download dictionary english_us_arpa
# Out:
# INFO - Saved model to f/root/Documents/MFA/pretrained_models/acoustic/english_us_arpa.zip, you can now use
#                 english_us_arpa in place of acoustic paths in mfa commands.
# INFO - Saved model to f/root/Documents/MFA/pretrained_models/acoustic/english_us_arpa.zip, you can now use
#                 english_us_arpa in place of acoustic paths in mfa commands.
# INFO - Saved model to f/root/Documents/MFA/pretrained_models/dictionary/english_us_arpa.dict, you can now use
#                 english_us_arpa in place of dictionary paths in mfa commands.
# INFO - Saved model to f/root/Documents/MFA/pretrained_models/dictionary/english_us_arpa.dict, you can now use
#                 english_us_arpa in place of dictionary paths in mfa commands.
# ...

# %%
# %%bash
# mfa model inspect acoustic english_us_arpa
# Out:
# - Acoustic model: english_us_arpa_None
#   - Version: 2.0.0rc4.dev19+ged818cb.d20220404
#   - Train date: 2022-05-11 11:19:39.314871
#   - Architecture: gmm-hmm
#   - Phone type: triphone
#   - Features:
#     - Feature type: mfcc
#     - Frame shift: 10
#     - Performs speaker adaptation: True
#     - Performs LDA on features: True
#
#   - Phones: AA, AA0, AA1, AA2, AE, AE0, AE1, AE2, AH, AH0, AH1, AH2, AO, AO0, AO1, AO2, AW, AW0, AW1, AW2, AY, AY0, AY1,
#             AY2, B, CH, D, DH, EH, EH0, EH1, EH2, ER, ER0, ER1, ER2, EY, EY0, EY1, EY2, F, G, HH, IH, IH0, IH1, IH2, IY,
#             IY0, IY1, IY2, JH, K, L, M, N, NG, OW, OW0, OW1, OW2, OY, OY0, OY1, OY2, P, R, S, SH, T, TH, UH, UH0, UH1,
#             UH2, UW, UW0, UW1, UW2, V, W, Y, Z, and ZH
# ...

# %%
# validate data
# %%bash
mfa validate /content/dataverse/wavs english_us_arpa english_us_arpa
# Out:
# INFO - Setting up corpus information...
# INFO - Loading corpus from source files...
# INFO - Found 1 speaker across 2800 files, average number of utterances per speaker: 2800.0
# INFO - Initializing multiprocessing jobs...
# WARNING - Number of jobs was specified as 3, but due to only having 1 speakers, MFA will only use 1 jobs.
# INFO - Creating corpus split for feature generation...
# INFO - Generating base features (mfcc)...
# INFO - Generating MFCCs...
# INFO - Calculating CMVN...
# INFO - Creating corpus split with features...
# INFO - Skipping transcription testing
# INFO - Finished initializing!
#
# INFO - ******
# INFO - Corpus
# INFO - ******
#
# INFO -   2800 sound files
# INFO -   0 text files
# INFO -   1 speakers
# INFO -   2800 utterances
# INFO -   5754.352 seconds total duration
#
# INFO -   Sound file read errors
# INFO -   ======================
#
# INFO -     There were no issues reading sound files.
#
# INFO -   Feature generation
# INFO -   ==================
#
# ...

# %%
# %%bash
# mfa align --overwrite --clean /content/dataverse english_us_arpa english_us_arpa /content/Text_Grids/dataverse_grid
# Out:
# INFO - Setting up corpus information...
# INFO - Loading corpus from source files...
# INFO - Found 1 speaker across 2800 files, average number of utterances per speaker: 2800.0
# INFO - Initializing multiprocessing jobs...
# WARNING - Number of jobs was specified as 3, but due to only having 1 speakers, MFA will only use 1 jobs.
# INFO - Creating corpus split for feature generation...
# INFO - Generating base features (mfcc)...
# INFO - Generating MFCCs...
# INFO - Calculating CMVN...
# INFO - Creating corpus split with features...
# INFO - Compiling training graphs...
# INFO - Performing first-pass alignment...
# INFO - Generating alignments...
# INFO - Calculating fMLLR for speaker adaptation...
# INFO - Performing second-pass alignment...
# INFO - Generating alignments...
# INFO - Exporting TextGrids to /content/Text_Grids/dataverse_grid...
# INFO - Collecting phone and word alignments from alignment lattices...
# ...

# %%
# %%bash
# mfa -h
# Out:
# usage: mfa [-h]
#            {version,align,adapt,train,validate,validate_dictionary,g2p,train_g2p,model,models,train_lm,train_dictionary,train_ivector,classify_speakers,create_segments,transcribe,configure,history,thirdparty,download,anchor,annotator}
#            ...
#
# positional arguments:
#   {version,align,adapt,train,validate,validate_dictionary,g2p,train_g2p,model,models,train_lm,train_dictionary,train_ivector,classify_speakers,create_segments,transcribe,configure,history,thirdparty,download,anchor,annotator}
#     align               Align a corpus with a pretrained acoustic model
#     adapt               Adapt an acoustic model to a new corpus
#     train               Train a new acoustic model on a corpus and optionally
#                         export alignments
#     validate            Validate a corpus for use in MFA
#     validate_dictionary
#                         Validate a dictionary using a G2P model to detect
# ...

# %%
# %%bash
# mfa align -h
# Out:
# usage: mfa align [-h] [--config_path CONFIG_PATH] [-s SPEAKER_CHARACTERS]
#                  [-a AUDIO_DIRECTORY]
#                  [--reference_directory REFERENCE_DIRECTORY]
#                  [--custom_mapping_path CUSTOM_MAPPING_PATH]
#                  [--output_format {long_textgrid,short_textgrid,json,csv}]
#                  [--include_original_text] [-t TEMPORARY_DIRECTORY]
#                  [--disable_mp] [-j NUM_JOBS] [-v] [-q] [--clean]
#                  [--overwrite] [--debug] [--disable_textgrid_cleanup]
#                  corpus_directory dictionary_path acoustic_model_path
#                  output_directory
#
# positional arguments:
#   corpus_directory      Full path to the directory to align
#   dictionary_path       Full path to pronunciation dictionary, or saved
#                         dictionary name (english_us_arpa)
#   acoustic_model_path   Full path to pre-trained acoustic model, or saved
#                         model name (english_us_arpa)
# ...
